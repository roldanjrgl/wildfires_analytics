# %%
# Import packages
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import earthpy as et

# %%
# Set working directory
os.chdir(os.path.join(et.io.HOME, 'nyu', 'rbda_project_data'))

# %%
# Create a path to the pre-fire MODIS h4 data
modis_c6_path = os.path.join("modis_c6_from_firms_11_25",
                             "DL_FIRE_M6_167819", 
                             "fire_archive_M6_167819.csv")

# %%
modis_c6_data = pd.read_csv(modis_c6_path)

# %%
modis_c6_data
# Out:
#         latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0        40.2989  -120.5715       300.7   1.1    1.0  2000-11-16      1903
# 1        40.2973  -120.5589       325.8   1.1    1.0  2000-11-16      1903
# 2        39.9942  -123.9034       326.6   1.5    1.2  2000-11-16      1903
# 3        39.9971  -123.9139       338.5   1.5    1.2  2000-11-16      1903
# 4        39.7069  -122.1806       301.7   1.2    1.1  2000-11-16      1903
# ...          ...        ...         ...   ...    ...         ...       ...
# 190911   41.1497  -123.4166       314.9   1.3    1.1  2020-07-31      2138
# 190912   41.1613  -123.4044       318.3   1.3    1.1  2020-07-31      2138
# 190913   41.1874  -123.4533       315.5   1.3    1.1  2020-07-31      2138
# 190914   41.1859  -123.4677       322.3   1.3    1.1  2020-07-31      2138
# 190915   41.1960  -123.4694       324.0   1.3    1.1  2020-07-31      2138
#
# ...

# %%
modis_c6_data.describe()
# Out:
#             latitude      longitude     brightness           scan  \
# count  190916.000000  190916.000000  190916.000000  190916.000000
# mean       38.040156    -120.657151     331.601759       1.642186
# std         2.588775       2.035685      28.753853       0.846242
# min        32.517200    -124.326500     300.000000       1.000000
# 25%        36.131000    -122.475250     312.400000       1.100000
# 50%        38.332300    -120.729800     324.200000       1.300000
# 75%        40.311300    -119.244600     340.900000       1.900000
# max        41.989400    -114.201600     505.000000       4.800000
#
#                track       acq_time     confidence       version  \
# count  190916.000000  190916.000000  190916.000000  1.909160e+05
# mean        1.220065    1564.434589      72.914119  6.030000e+00
# std         0.256110     616.810333      24.158319  2.133233e-11
# min         1.000000     458.000000       0.000000  6.030000e+00
# ...

# %%
# See first 5 rows
modis_c6_data.head()
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0   40.2989  -120.5715       300.7   1.1    1.0  2000-11-16      1903
# 1   40.2973  -120.5589       325.8   1.1    1.0  2000-11-16      1903
# 2   39.9942  -123.9034       326.6   1.5    1.2  2000-11-16      1903
# 3   39.9971  -123.9139       338.5   1.5    1.2  2000-11-16      1903
# 4   39.7069  -122.1806       301.7   1.2    1.1  2000-11-16      1903
#
#   satellite instrument  confidence  version  bright_t31   frp daynight  type
# 0     Terra      MODIS          35     6.03       273.1   9.8        D     0
# 1     Terra      MODIS          84     6.03       274.7  32.4        D     0
# 2     Terra      MODIS          85     6.03       280.1  52.0        D     0
# 3     Terra      MODIS          91     6.03       280.2  80.9        D     0
# 4     Terra      MODIS          49     6.03       286.3   6.9        D     0

# %%
# See last 5 rows
modis_c6_data.tail()
# Out:
#         latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 190911   41.1497  -123.4166       314.9   1.3    1.1  2020-07-31      2138
# 190912   41.1613  -123.4044       318.3   1.3    1.1  2020-07-31      2138
# 190913   41.1874  -123.4533       315.5   1.3    1.1  2020-07-31      2138
# 190914   41.1859  -123.4677       322.3   1.3    1.1  2020-07-31      2138
# 190915   41.1960  -123.4694       324.0   1.3    1.1  2020-07-31      2138
#
#        satellite instrument  confidence  version  bright_t31   frp daynight  \
# 190911      Aqua      MODIS          17     6.03       303.4   9.6        D
# 190912      Aqua      MODIS          40     6.03       305.9  15.5        D
# 190913      Aqua      MODIS          21     6.03       297.2  13.3        D
# 190914      Aqua      MODIS          69     6.03       299.6  22.4        D
# 190915      Aqua      MODIS          63     6.03       298.7  24.7        D
#
#         type
# 190911     0
# 190912     0
# 190913     0
# ...

# %%
# info about modis_c6_data dataframe
modis_c6_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190916 entries, 0 to 190915
# Data columns (total 15 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   latitude    190916 non-null  float64
#  1   longitude   190916 non-null  float64
#  2   brightness  190916 non-null  float64
#  3   scan        190916 non-null  float64
#  4   track       190916 non-null  float64
#  5   acq_date    190916 non-null  object
#  6   acq_time    190916 non-null  int64
#  7   satellite   190916 non-null  object
#  8   instrument  190916 non-null  object
#  9   confidence  190916 non-null  int64
#  10  version     190916 non-null  float64
#  11  bright_t31  190916 non-null  float64
#  12  frp         190916 non-null  float64
#  13  daynight    190916 non-null  object
#  14  type        190916 non-null  int64
# dtypes: float64(8), int64(3), object(4)
# memory usage: 21.8+ MB

# %%
# Get column names
modis_c6_data.columns
# Out:
# Index(['latitude', 'longitude', 'brightness', 'scan', 'track', 'acq_date',
#        'acq_time', 'satellite', 'instrument', 'confidence', 'version',
#        'bright_t31', 'frp', 'daynight', 'type'],
#       dtype='object')

# %%
# Number of rows and columns 
modis_c6_data.shape
# Out:
# (190916, 15)

# %%
# Summary of stats of all numeric columns
modis_c6_data.describe()
# Out:
#             latitude      longitude     brightness           scan  \
# count  190916.000000  190916.000000  190916.000000  190916.000000
# mean       38.040156    -120.657151     331.601759       1.642186
# std         2.588775       2.035685      28.753853       0.846242
# min        32.517200    -124.326500     300.000000       1.000000
# 25%        36.131000    -122.475250     312.400000       1.100000
# 50%        38.332300    -120.729800     324.200000       1.300000
# 75%        40.311300    -119.244600     340.900000       1.900000
# max        41.989400    -114.201600     505.000000       4.800000
#
#                track       acq_time     confidence       version  \
# count  190916.000000  190916.000000  190916.000000  1.909160e+05
# mean        1.220065    1564.434589      72.914119  6.030000e+00
# std         0.256110     616.810333      24.158319  2.133233e-11
# min         1.000000     458.000000       0.000000  6.030000e+00
# ...

# %%
# Median of all numeric columns
modis_c6_data.median()
# Out:
# latitude        38.3323
# longitude     -120.7298
# brightness     324.2000
# scan             1.3000
# track            1.1000
# acq_time      1903.0000
# confidence      76.0000
# version          6.0300
# bright_t31     296.2000
# frp             30.3000
# type             0.0000
# dtype: float64

# %%
# Summary stats on latitude column as dataframe
modis_c6_data[["latitude"]].describe()
# Out:
#             latitude
# count  190916.000000
# mean       38.040156
# std         2.588775
# min        32.517200
# 25%        36.131000
# 50%        38.332300
# 75%        40.311300
# max        41.989400

# %%
# Summary of stats on latitude column as series
modis_c6_data["latitude"].describe()
# Out:
# count    190916.000000
# mean         38.040156
# std           2.588775
# min          32.517200
# 25%          36.131000
# 50%          38.332300
# 75%          40.311300
# max          41.989400
# Name: latitude, dtype: float64

# %%
modis_c6_data.sort_values(by="brightness", 
                          ascending=False)
# Out:
#         latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 176815   40.9558  -122.4502       505.0   1.2    1.1  2018-09-05      2132
# 172238   40.8399  -122.5426       504.9   1.5    1.2  2018-08-11      2139
# 100146   40.1734  -121.1756       504.9   1.1    1.0  2012-08-21      2119
# 172192   40.8382  -122.5601       504.8   1.5    1.2  2018-08-11      2139
# 108213   37.9458  -119.8940       504.8   1.5    1.2  2013-08-22      2131
# ...          ...        ...         ...   ...    ...         ...       ...
# 91999    36.2970  -118.5199       300.0   1.9    1.3  2011-07-26       926
# 90624    40.0847  -122.6310       300.0   1.4    1.2  2011-02-10      1926
# 82651    36.1496  -118.2097       300.0   1.2    1.1  2009-08-11       613
# 122916   41.6923  -123.8791       300.0   1.1    1.1  2015-03-09      1927
# 65729    40.7842  -123.5418       300.0   1.6    1.2  2008-07-03       639
#
# ...

# %%
# Plot data 
# f, ax = plt.subplots()

# ax.bar(x=modis_c6_data.latitude,
#        height= modis_c6_data.brightness,
#        color="purple")

# ax.set(title="Plot of latitude vs brightness (test)")
# plt.show()

# %%
modis_c6_data.groupby(['daynight'])[["latitude"]].describe()
# Out:
#           latitude                                                    \
#              count       mean       std      min        25%      50%
# daynight
# D         124502.0  37.860432  2.502409  32.5172  36.111125  37.9795
# N          66414.0  38.377073  2.711471  32.5226  36.168625  39.0169
#
#
#                75%      max
# daynight
# D         39.87775  41.9894
# N         40.76670  41.9892
